# %%
import pandas as pd
import numpy as np

path = r"/root/Analysis_CO2_Emission_Prj/Merge_Data/final.csv"
df = pd.read_csv(path)
data_area = [
  {"country":"Aruba","area_ha":18000},
  {"country":"Afghanistan","area_ha":65286400},
  {"country":"Angola","area_ha":124670000},
  {"country":"Anguilla","area_ha":9100},
  {"country":"Åland Islands","area_ha":158000},
  {"country":"Albania","area_ha":2874800},
  {"country":"Andorra","area_ha":46800},
  {"country":"United Arab Emirates","area_ha":8360000},
  {"country":"Argentina","area_ha":278040000},
  {"country":"Armenia","area_ha":2974300},
  {"country":"American Samoa","area_ha":19900},
  {"country":"Antarctica","area_ha":1420000000},
  {"country":"French Southern Territories","area_ha":774700},
  {"country":"Antigua and Barbuda","area_ha":44260},
  {"country":"Australia","area_ha":769202400},
  {"country":"Austria","area_ha":8387100},
  {"country":"Azerbaijan","area_ha":8660000},
  {"country":"Burundi","area_ha":2783400},
  {"country":"Belgium","area_ha":3052800},
  {"country":"Benin","area_ha":11476300},
  {"country":"Bonaire, Sint Eustatius and Saba","area_ha":32800},
  {"country":"Burkina Faso","area_ha":27420000},
  {"country":"Bangladesh","area_ha":14846000},
  {"country":"Bulgaria","area_ha":11099400},
  {"country":"Bahrain","area_ha":76000},
  {"country":"Bahamas","area_ha":1394300},
  {"country":"Bosnia and Herzegovina","area_ha":5120900},
  {"country":"Saint Barthélemy","area_ha":2100},
  {"country":"Belarus","area_ha":20760000},
  {"country":"Belize","area_ha":2296600},
  {"country":"Bermuda","area_ha":5400},
  {"country":"Bolivia, Plurinational State of","area_ha":109858100},
  {"country":"Brazil","area_ha":851576700},
  {"country":"Barbados","area_ha":43000},
  {"country":"Brunei Darussalam","area_ha":576500},
  {"country":"Bhutan","area_ha":3839400},
  {"country":"Bouvet Island","area_ha":4900},
  {"country":"Botswana","area_ha":58173000},
  {"country":"Central African Republic","area_ha":62298400},
  {"country":"Canada","area_ha":998467000},
  {"country":"Cocos (Keeling) Islands","area_ha":1400},
  {"country":"Switzerland","area_ha":4128500},
  {"country":"Chile","area_ha":75610200},
  {"country":"China","area_ha":959696100},
  {"country":"Côte d'Ivoire","area_ha":32246300},
  {"country":"Cameroon","area_ha":47544200},
  {"country":"Congo, The Democratic Republic of the","area_ha":234485800},
  {"country":"Congo","area_ha":34200000},
  {"country":"Cook Islands","area_ha":23600},
  {"country":"Colombia","area_ha":114174800},
  {"country":"Comoros","area_ha":223500},
  {"country":"Cabo Verde","area_ha":403300},
  {"country":"Costa Rica","area_ha":5110000},
  {"country":"Cuba","area_ha":10988400},
  {"country":"Curaçao","area_ha":44400},
  {"country":"Christmas Island","area_ha":13500},
  {"country":"Cayman Islands","area_ha":26400},
  {"country":"Cyprus","area_ha":925100},
  {"country":"Czechia","area_ha":7886700},
  {"country":"Germany","area_ha":35702200},
  {"country":"Djibouti","area_ha":2320000},
  {"country":"Dominica","area_ha":75100},
  {"country":"Denmark","area_ha":4309400},
  {"country":"Dominican Republic","area_ha":4867100},
  {"country":"Algeria","area_ha":238174100},
  {"country":"Ecuador","area_ha":28356100},
  {"country":"Egypt","area_ha":100245000},
  {"country":"Eritrea","area_ha":11760000},
  {"country":"Western Sahara","area_ha":26600000},
  {"country":"Spain","area_ha":50599200},
  {"country":"Estonia","area_ha":4522700},
  {"country":"Ethiopia","area_ha":110430000},
  {"country":"Finland","area_ha":33842400},
  {"country":"Fiji","area_ha":1827400},
  {"country":"Falkland Islands (Malvinas)","area_ha":1217300},
  {"country":"France","area_ha":64380100},
  {"country":"Faroe Islands","area_ha":139900},
  {"country":"Micronesia, Federated States of","area_ha":70200},
  {"country":"Gabon","area_ha":26766700},
  {"country":"United Kingdom","area_ha":24361000},
  {"country":"Georgia","area_ha":6970000},
  {"country":"Guernsey","area_ha":7800},
  {"country":"Ghana","area_ha":23853300},
  {"country":"Gibraltar","area_ha":680},
  {"country":"Guinea","area_ha":24585700},
  {"country":"Guadeloupe","area_ha":162800},
  {"country":"Gambia","area_ha":1129500},
  {"country":"Guinea-Bissau","area_ha":3612500},
  {"country":"Equatorial Guinea","area_ha":2805100},
  {"country":"Greece","area_ha":13195700},
  {"country":"Grenada","area_ha":34400},
  {"country":"Greenland","area_ha":216608600},
  {"country":"Guatemala","area_ha":10888900},
  {"country":"French Guiana","area_ha":8353400},
  {"country":"Guam","area_ha":54400},
  {"country":"Guyana","area_ha":21496900},
  {"country":"Hong Kong","area_ha":110400},
  {"country":"Heard Island and McDonald Islands","area_ha":41200},
  {"country":"Honduras","area_ha":11249200},
  {"country":"Croatia","area_ha":5659400},
  {"country":"Haiti","area_ha":2775000},
  {"country":"Hungary","area_ha":9302800},
  {"country":"Indonesia","area_ha":190456900},
  {"country":"Isle of Man","area_ha":57200},
  {"country":"India","area_ha":328726300},
  {"country":"British Indian Ocean Territory","area_ha":6000},
  {"country":"Ireland","area_ha":7027300},
  {"country":"Iran, Islamic Republic of","area_ha":164819500},
  {"country":"Iraq","area_ha":43831700},
  {"country":"Iceland","area_ha":10300000},
  {"country":"Israel","area_ha":2077000},
  {"country":"Italy","area_ha":30134000},
  {"country":"Jamaica","area_ha":1099100},
  {"country":"Jersey","area_ha":11600},
  {"country":"Jordan","area_ha":8934200},
  {"country":"Japan","area_ha":37797500},
  {"country":"Kazakhstan","area_ha":272490000},
  {"country":"Kenya","area_ha":58036700},
  {"country":"Kyrgyzstan","area_ha":19995100},
  {"country":"Cambodia","area_ha":18103500},
  {"country":"Kiribati","area_ha":81100},
  {"country":"Saint Kitts and Nevis","area_ha":26100},
  {"country":"Korea, Republic of","area_ha":10021000},
  {"country":"Kuwait","area_ha":1781800},
  {"country":"Lao People's Democratic Republic","area_ha":23680000},
  {"country":"Lebanon","area_ha":1045200},
  {"country":"Liberia","area_ha":11136900},
  {"country":"Libya","area_ha":175954000},
  {"country":"Saint Lucia","area_ha":61600},
  {"country":"Liechtenstein","area_ha":16000},
  {"country":"Sri Lanka","area_ha":6561000},
  {"country":"Lesotho","area_ha":3035500},
  {"country":"Lithuania","area_ha":6530000},
  {"country":"Luxembourg","area_ha":258600},
  {"country":"Latvia","area_ha":6458900},
  {"country":"Macao","area_ha":3000},
  {"country":"Saint Martin (French part)","area_ha":5300},
  {"country":"Morocco","area_ha":44655000},
  {"country":"Monaco","area_ha":202},
  {"country":"Moldova, Republic of","area_ha":3384600},
  {"country":"Madagascar","area_ha":58704100},
  {"country":"Maldives","area_ha":30000},
  {"country":"Mexico","area_ha":196437500},
  {"country":"Marshall Islands","area_ha":18100},
  {"country":"North Macedonia","area_ha":2571300},
  {"country":"Mali","area_ha":124019200},
  {"country":"Malta","area_ha":31600},
  {"country":"Myanmar","area_ha":67657800},
  {"country":"Montenegro","area_ha":1381200},
  {"country":"Mongolia","area_ha":156411600},
  {"country":"Northern Mariana Islands","area_ha":46400},
  {"country":"Mozambique","area_ha":80159000},
  {"country":"Mauritania","area_ha":103070000},
  {"country":"Montserrat","area_ha":10200},
  {"country":"Martinique","area_ha":112800},
  {"country":"Mauritius","area_ha":204000},
  {"country":"Malawi","area_ha":11848400},
  {"country":"Malaysia","area_ha":32984700},
  {"country":"Mayotte","area_ha":37400},
  {"country":"Namibia","area_ha":82561500},
  {"country":"New Caledonia","area_ha":1857500},
  {"country":"Niger","area_ha":126700000},
  {"country":"Norfolk Island","area_ha":3600},
  {"country":"Nigeria","area_ha":92376800},
  {"country":"Nicaragua","area_ha":13037300},
  {"country":"Niue","area_ha":26000},
  {"country":"Netherlands","area_ha":4154300},
  {"country":"Norway","area_ha":32380200},
  {"country":"Nepal","area_ha":14718100},
  {"country":"Nauru","area_ha":2100},
  {"country":"New Zealand","area_ha":26883800},
  {"country":"Oman","area_ha":30950000},
  {"country":"Pakistan","area_ha":88191300},
  {"country":"Panama","area_ha":7541700},
  {"country":"Pitcairn","area_ha":4700},
  {"country":"Peru","area_ha":128521600},
  {"country":"Philippines","area_ha":30000000},
  {"country":"Palau","area_ha":45900},
  {"country":"Papua New Guinea","area_ha":46284000},
  {"country":"Poland","area_ha":31268500},
  {"country":"Puerto Rico","area_ha":910400},
  {"country":"Korea, Democratic People's Republic of","area_ha":12053800},
  {"country":"Portugal","area_ha":9209000},
  {"country":"Paraguay","area_ha":40675200},
  {"country":"Palestine, State of","area_ha":622000},
  {"country":"French Polynesia","area_ha":416700},
  {"country":"Qatar","area_ha":1158600},
  {"country":"Réunion","area_ha":251100},
  {"country":"Romania","area_ha":23839700},
  {"country":"Russian Federation","area_ha":1709824200},
  {"country":"Rwanda","area_ha":2633800},
  {"country":"Saudi Arabia","area_ha":214969000},
  {"country":"Sudan","area_ha":186148400},
  {"country":"Senegal","area_ha":19672200},
  {"country":"Singapore","area_ha":71900},
  {"country":"South Georgia and the South Sandwich Islands","area_ha":390300},
  {"country":"Saint Helena, Ascension and Tristan da Cunha","area_ha":39400},
  {"country":"Svalbard and Jan Mayen","area_ha":6102200},
  {"country":"Solomon Islands","area_ha":2889600},
  {"country":"Sierra Leone","area_ha":7174000},
  {"country":"El Salvador","area_ha":2104100},
  {"country":"San Marino","area_ha":6100},
  {"country":"Somalia","area_ha":63765700},
  {"country":"Saint Pierre and Miquelon","area_ha":24200},
  {"country":"Serbia","area_ha":8836100},
  {"country":"South Sudan","area_ha":64432900},
  {"country":"Sao Tome and Principe","area_ha":96400},
  {"country":"Suriname","area_ha":16382000},
  {"country":"Slovakia","area_ha":4903500},
  {"country":"Slovenia","area_ha":2027300},
  {"country":"Sweden","area_ha":45029500},
  {"country":"Eswatini","area_ha":1736400},
  {"country":"Sint Maarten (Dutch part)","area_ha":3400},
  {"country":"Seychelles","area_ha":45500},
  {"country":"Syrian Arab Republic","area_ha":18518000},
  {"country":"Turks and Caicos Islands","area_ha":94800},
  {"country":"Chad","area_ha":128400000},
  {"country":"Togo","area_ha":5678500},
  {"country":"Thailand","area_ha":51312000},
  {"country":"Tajikistan","area_ha":14310000},
  {"country":"Tokelau","area_ha":1200},
  {"country":"Turkmenistan","area_ha":48810000},
  {"country":"Timor-Leste","area_ha":1487400},
  {"country":"Tonga","area_ha":74700},
  {"country":"Trinidad and Tobago","area_ha":513100},
  {"country":"Tunisia","area_ha":16361000},
  {"country":"Türkiye","area_ha":78356200},
  {"country":"Tuvalu","area_ha":2600},
  {"country":"Taiwan, Province of China","area_ha":3619300},
  {"country":"Tanzania, United Republic of","area_ha":94730300},
  {"country":"Uganda","area_ha":24155000},
  {"country":"Ukraine","area_ha":60350000},
  {"country":"United States Minor Outlying Islands","area_ha":3420},
  {"country":"Uruguay","area_ha":17621500},
  {"country":"United States","area_ha":983352000},
  {"country":"Uzbekistan","area_ha":44740000},
  {"country":"Holy See (Vatican City State)","area_ha":44},
  {"country":"Saint Vincent and the Grenadines","area_ha":38900},
  {"country":"Venezuela, Bolivarian Republic of","area_ha":91644500},
  {"country":"Virgin Islands, British","area_ha":15100},
  {"country":"Virgin Islands, U.S.","area_ha":34600},
  {"country":"Viet Nam","area_ha":33121200},
  {"country":"Vanuatu","area_ha":1218900},
  {"country":"Wallis and Futuna","area_ha":14200},
  {"country":"Samoa","area_ha":283100},
  {"country":"Yemen","area_ha":52796800},
  {"country":"South Africa","area_ha":122103700},
  {"country":"Zambia","area_ha":75261800},
  {"country":"Zimbabwe","area_ha":39075700}
]

df_area = pd.DataFrame(data_area)
country_to_area_map = df_area.set_index('country')['area_ha']
df['ft_area_ha'] = df['country'].map(country_to_area_map)
nan_area_count = df['ft_area_ha'].isna().sum()
nan_area_count

df.to_csv(r"/root/Analysis_CO2_Emission_Prj/eda_output_an/final_filled_area_ha_country.csv", index=False)
